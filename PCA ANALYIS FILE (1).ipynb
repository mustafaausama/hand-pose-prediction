# %%
import pandas as pd


X = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\joint_x.csv',index_col=None)
Y = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\joint_y.csv',index_col=None)
Z = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\joint_z.csv',index_col=None) 

F1_KNU3_A_x = X[['F1_KNU3_A']]
F1_KNU3_B_x = X[['F1_KNU3_B']]
F1_KNU2_A_x = X[['F1_KNU2_A']]
F1_KNU2_B_x = X[['F1_KNU2_B']]
F1_KNU1_A_x = X[['F1_KNU1_A']]
F1_KNU1_B_x = X[['F1_KNU1_B']]
F2_KNU3_A_x = X[['F2_KNU3_A']]
F2_KNU3_B_x = X[['F2_KNU3_B']]
F2_KNU2_A_x = X[['F2_KNU2_A']]
F2_KNU2_B_x = X[['F2_KNU2_B']]
F2_KNU1_A_x = X[['F2_KNU1_A']]
F2_KNU1_B_x = X[['F2_KNU1_B']]
F3_KNU3_A_x = X[['F3_KNU3_A']]
F3_KNU3_B_x = X[['F3_KNU3_B']]
F3_KNU2_A_x = X[['F3_KNU2_A']]
F3_KNU2_B_x = X[['F3_KNU2_B']]
F3_KNU1_A_x = X[['F3_KNU1_A']]
F3_KNU1_B_x = X[['F3_KNU1_B']]
F4_KNU3_A_x = X[['F4_KNU3_A']]
F4_KNU3_B_x = X[['F4_KNU3_B']]
F4_KNU2_A_x = X[['F4_KNU2_A']]
F4_KNU2_B_x = X[['F4_KNU2_B']]
F4_KNU1_A_x = X[['F4_KNU1_A']]
F4_KNU1_B_x = X[['F4_KNU1_B']]
TH_KNU3_A_x = X[['TH_KNU3_A']]
TH_KNU3_B_x = X[['TH_KNU3_B']]
TH_KNU2_A_x = X[['TH_KNU2_A']]
TH_KNU2_B_x = X[['TH_KNU2_B']]
TH_KNU1_A_x = X[['TH_KNU1_A']]
TH_KNU1_B_x = X[['TH_KNU1_B']]
PALM_1_x    = X[['PALM_1']]
PALM_2_x    = X[['PALM_2']]
PALM_3_x    = X[['PALM_3']]
PALM_4_x    = X[['PALM_4']]
PALM_5_x    = X[['PALM_5']]
PALM_6_x    = X[['PALM_6']]

###############################################################################################################

F1_KNU3_A_y = Y[['F1_KNU3_A']]
F1_KNU3_B_y = Y[['F1_KNU3_B']]
F1_KNU2_A_y = Y[['F1_KNU2_A']]
F1_KNU2_B_y = Y[['F1_KNU2_B']]
F1_KNU1_A_y = Y[['F1_KNU1_A']]
F1_KNU1_B_y = Y[['F1_KNU1_B']]
F2_KNU3_A_y = Y[['F2_KNU3_A']]
F2_KNU3_B_y = Y[['F2_KNU3_B']]
F2_KNU2_A_y = Y[['F2_KNU2_A']]
F2_KNU2_B_y = Y[['F2_KNU2_B']]
F2_KNU1_A_y = Y[['F2_KNU1_A']]
F2_KNU1_B_y = Y[['F2_KNU1_B']]
F3_KNU3_A_y = Y[['F3_KNU3_A']]
F3_KNU3_B_y = Y[['F3_KNU3_B']]
F3_KNU2_A_y = Y[['F3_KNU2_A']]
F3_KNU2_B_y = Y[['F3_KNU2_B']]
F3_KNU1_A_y = Y[['F3_KNU1_A']]
F3_KNU1_B_y = Y[['F3_KNU1_B']]
F4_KNU3_A_y = Y[['F4_KNU3_A']]
F4_KNU3_B_y = Y[['F4_KNU3_B']]
F4_KNU2_A_y = Y[['F4_KNU2_A']]
F4_KNU2_B_y = Y[['F4_KNU2_B']]
F4_KNU1_A_y = Y[['F4_KNU1_A']]
F4_KNU1_B_y = Y[['F4_KNU1_B']]
TH_KNU3_A_y = Y[['TH_KNU3_A']]
TH_KNU3_B_y = Y[['TH_KNU3_B']]
TH_KNU2_A_y = Y[['TH_KNU2_A']]
TH_KNU2_B_y = Y[['TH_KNU2_B']]
TH_KNU1_A_y = Y[['TH_KNU1_A']]
TH_KNU1_B_y = Y[['TH_KNU1_B']]
PALM_1_y    = Y[['PALM_1']]
PALM_2_y    = Y[['PALM_2']]
PALM_3_y    = Y[['PALM_3']]
PALM_4_y    = Y[['PALM_4']]
PALM_5_y    = Y[['PALM_5']]
PALM_6_y    = Y[['PALM_6']]



##############################################################################################################

F1_KNU3_A_z = Z[['F1_KNU3_A']]
F1_KNU3_B_z = Z[['F1_KNU3_B']]
F1_KNU2_A_z = Z[['F1_KNU2_A']]
F1_KNU2_B_z = Z[['F1_KNU2_B']]
F1_KNU1_A_z = Z[['F1_KNU1_A']]
F1_KNU1_B_z = Z[['F1_KNU1_B']]
F2_KNU3_A_z = Z[['F2_KNU3_A']]
F2_KNU3_B_z = Z[['F2_KNU3_B']]
F2_KNU2_A_z = Z[['F2_KNU2_A']]
F2_KNU2_B_z = Z[['F2_KNU2_B']]
F2_KNU1_A_z = Z[['F2_KNU1_A']]
F2_KNU1_B_z = Z[['F2_KNU1_B']]
F3_KNU3_A_z = Z[['F3_KNU3_A']]
F3_KNU3_B_z = Z[['F3_KNU3_B']]
F3_KNU2_A_z = Z[['F3_KNU2_A']]
F3_KNU2_B_z = Z[['F3_KNU2_B']]
F3_KNU1_A_z = Z[['F3_KNU1_A']]
F3_KNU1_B_z = Z[['F3_KNU1_B']]
F4_KNU3_A_z = Z[['F4_KNU3_A']]
F4_KNU3_B_z = Z[['F4_KNU3_B']]
F4_KNU2_A_z = Z[['F4_KNU2_A']]
F4_KNU2_B_z = Z[['F4_KNU2_B']]
F4_KNU1_A_z = Z[['F4_KNU1_A']]
F4_KNU1_B_z = Z[['F4_KNU1_B']]
TH_KNU3_A_z = Z[['TH_KNU3_A']]
TH_KNU3_B_z = Z[['TH_KNU3_B']]
TH_KNU2_A_z = Z[['TH_KNU2_A']]
TH_KNU2_B_z = Z[['TH_KNU2_B']]
TH_KNU1_A_z = Z[['TH_KNU1_A']]
TH_KNU1_B_z = Z[['TH_KNU1_B']]
PALM_1_z    = Z[['PALM_1']]
PALM_2_z    = Z[['PALM_2']]
PALM_3_z    = Z[['PALM_3']]
PALM_4_z    = Z[['PALM_4']]
PALM_5_z    = Z[['PALM_5']]
PALM_6_z    = Z[['PALM_6']]




##############################################################################################

F1_KNU3_A = pd.concat([F1_KNU3_A_x, F1_KNU3_A_y,F1_KNU3_A_z], axis=1, join='inner')
F1_KNU3_B = pd.concat([F1_KNU3_B_x, F1_KNU3_B_y,F1_KNU3_B_z], axis=1, join='inner')
F1_KNU2_A = pd.concat([F1_KNU2_A_x, F1_KNU2_A_y,F1_KNU2_A_z], axis=1, join='inner')
F1_KNU2_B = pd.concat([F1_KNU2_B_x, F1_KNU2_B_y,F1_KNU2_B_z], axis=1, join='inner')
F1_KNU1_A = pd.concat([F1_KNU1_A_x, F1_KNU1_A_y,F1_KNU1_A_z], axis=1, join='inner')
F1_KNU1_B = pd.concat([F1_KNU1_B_x, F1_KNU1_B_y,F1_KNU1_B_z], axis=1, join='inner')
F2_KNU3_A = pd.concat([F2_KNU3_A_x, F2_KNU3_A_y,F2_KNU3_A_z], axis=1, join='inner')
F2_KNU3_B = pd.concat([F2_KNU3_B_x, F2_KNU3_B_y,F2_KNU3_B_z], axis=1, join='inner')
F2_KNU2_A = pd.concat([F2_KNU2_A_x, F2_KNU2_A_y,F2_KNU2_A_z], axis=1, join='inner')
F2_KNU2_B = pd.concat([F2_KNU2_B_x, F2_KNU2_B_y,F2_KNU2_B_z], axis=1, join='inner')
F2_KNU1_A = pd.concat([F2_KNU1_A_x, F2_KNU1_A_y,F2_KNU1_A_z], axis=1, join='inner')
F2_KNU1_B = pd.concat([F2_KNU1_B_x, F2_KNU1_B_y,F2_KNU1_B_z], axis=1, join='inner')
F3_KNU3_A = pd.concat([F3_KNU3_A_x, F3_KNU3_A_y,F3_KNU3_A_z], axis=1, join='inner')
F3_KNU3_B = pd.concat([F3_KNU3_B_x, F3_KNU3_B_y,F3_KNU3_B_z], axis=1, join='inner')
F3_KNU2_A = pd.concat([F3_KNU2_A_x, F3_KNU2_A_y,F3_KNU2_A_z], axis=1, join='inner')
F3_KNU2_B = pd.concat([F3_KNU2_B_x, F3_KNU2_B_y,F3_KNU2_B_z], axis=1, join='inner')
F3_KNU1_A = pd.concat([F3_KNU1_A_x, F3_KNU1_A_y,F3_KNU1_A_z], axis=1, join='inner')
F3_KNU1_B = pd.concat([F3_KNU1_B_x, F3_KNU1_B_y,F3_KNU1_B_z], axis=1, join='inner')
F4_KNU3_A = pd.concat([F4_KNU3_A_x, F4_KNU3_A_y,F4_KNU3_A_z], axis=1, join='inner')
F4_KNU3_B = pd.concat([F4_KNU3_B_x, F4_KNU3_B_y,F4_KNU3_B_z], axis=1, join='inner')
F4_KNU2_A = pd.concat([F4_KNU2_A_x, F4_KNU2_A_y,F4_KNU2_A_z], axis=1, join='inner')
F4_KNU2_B = pd.concat([F4_KNU2_B_x, F4_KNU2_B_y,F4_KNU2_B_z], axis=1, join='inner')
F4_KNU1_A = pd.concat([F4_KNU1_A_x, F4_KNU1_A_y,F4_KNU1_A_z], axis=1, join='inner')
F4_KNU1_B = pd.concat([F4_KNU1_B_x, F4_KNU1_B_y,F4_KNU1_B_z], axis=1, join='inner')
TH_KNU3_A = pd.concat([TH_KNU3_A_x, TH_KNU3_A_y,TH_KNU3_A_z], axis=1, join='inner')
TH_KNU3_B = pd.concat([TH_KNU3_B_x, TH_KNU3_B_y,TH_KNU3_B_z], axis=1, join='inner')
TH_KNU2_A = pd.concat([TH_KNU2_A_x, TH_KNU2_A_y,TH_KNU2_A_z], axis=1, join='inner')
TH_KNU2_B = pd.concat([TH_KNU2_B_x, TH_KNU2_B_y,TH_KNU2_B_z], axis=1, join='inner')
TH_KNU1_A = pd.concat([TH_KNU1_A_x, TH_KNU1_A_y,TH_KNU1_A_z], axis=1, join='inner')
TH_KNU1_B = pd.concat([TH_KNU1_B_x, TH_KNU1_B_y,TH_KNU1_B_z], axis=1, join='inner')
PALM_1    = pd.concat([PALM_1_x, PALM_1_y,PALM_1_z], axis=1, join='inner')
PALM_2    = pd.concat([PALM_2_x, PALM_2_y,PALM_2_z], axis=1, join='inner')
PALM_3    = pd.concat([PALM_3_x, PALM_3_y,PALM_3_z], axis=1, join='inner')
PALM_4    = pd.concat([PALM_4_x, PALM_4_y,PALM_4_z], axis=1, join='inner')
PALM_5    = pd.concat([PALM_5_x, PALM_5_y,PALM_5_z], axis=1, join='inner')
PALM_6    = pd.concat([PALM_6_x, PALM_6_y,PALM_6_z], axis=1, join='inner')





# MEAN 0 AND VARIANCE 1 
# STANDARDIZING
from sklearn.preprocessing import StandardScaler

############################################################################
F1_KNU3_A_ss = StandardScaler()
F1_KNU3_A_ss.fit(F1_KNU3_A)
##############################################################
############################################################################
F1_KNU3_B_ss = StandardScaler()
F1_KNU3_B_ss.fit(F1_KNU3_B)
##############################################################
############################################################################
F1_KNU2_A_ss = StandardScaler()
F1_KNU2_A_ss.fit(F1_KNU2_A)
##############################################################
############################################################################
F1_KNU2_B_ss = StandardScaler()
F1_KNU2_B_ss.fit(F1_KNU2_B)
##############################################################
############################################################################
F1_KNU1_A_ss = StandardScaler()
F1_KNU1_A_ss.fit(F1_KNU1_A)
##############################################################
############################################################################
F1_KNU1_B_ss = StandardScaler()
F1_KNU1_B_ss.fit(F1_KNU1_B)
##############################################################
############################################################################
F2_KNU3_A_ss = StandardScaler()
F2_KNU3_A_ss.fit(F2_KNU3_A)
##############################################################
############################################################################
F2_KNU3_B_ss = StandardScaler()
F2_KNU3_B_ss.fit(F2_KNU3_B)
##############################################################
############################################################################
F2_KNU2_A_ss = StandardScaler()
F2_KNU2_A_ss.fit(F2_KNU2_A)
##############################################################
############################################################################
F2_KNU2_B_ss = StandardScaler()
F2_KNU2_B_ss.fit(F2_KNU2_B)
##############################################################
############################################################################
F2_KNU1_A_ss = StandardScaler()
F2_KNU1_A_ss.fit(F2_KNU1_A)
##############################################################
############################################################################
F2_KNU1_B_ss = StandardScaler()
F2_KNU1_B_ss.fit(F2_KNU1_B)
##############################################################
############################################################################
F3_KNU3_A_ss = StandardScaler()
F3_KNU3_A_ss.fit(F3_KNU3_A)
##############################################################
############################################################################
F3_KNU3_B_ss = StandardScaler()
F3_KNU3_B_ss.fit(F3_KNU3_B)
##############################################################
############################################################################
F3_KNU2_A_ss = StandardScaler()
F3_KNU2_A_ss.fit(F3_KNU2_A)
##############################################################
############################################################################
F3_KNU2_B_ss = StandardScaler()
F3_KNU2_B_ss.fit(F3_KNU2_B)
##############################################################
############################################################################
F3_KNU1_A_ss = StandardScaler()
F3_KNU1_A_ss.fit(F3_KNU1_A)
##############################################################
############################################################################
F3_KNU1_B_ss = StandardScaler()
F3_KNU1_B_ss.fit(F3_KNU1_B)
##############################################################
############################################################################
F4_KNU3_A_ss = StandardScaler()
F4_KNU3_A_ss.fit(F4_KNU3_A)
##############################################################
############################################################################
F4_KNU3_B_ss = StandardScaler()
F4_KNU3_B_ss.fit(F4_KNU3_B)
##############################################################
############################################################################
F4_KNU2_A_ss = StandardScaler()
F4_KNU2_A_ss.fit(F4_KNU2_A)
##############################################################
############################################################################
F4_KNU2_B_ss = StandardScaler()
F4_KNU2_B_ss.fit(F4_KNU2_B)
##############################################################
############################################################################
F4_KNU1_A_ss = StandardScaler()
F4_KNU1_A_ss.fit(F4_KNU1_A)
##############################################################
############################################################################
F4_KNU1_B_ss = StandardScaler()
F4_KNU1_B_ss.fit(F4_KNU1_B)
##############################################################
############################################################################
TH_KNU3_A_ss = StandardScaler()
TH_KNU3_A_ss.fit(TH_KNU3_A)
##############################################################
############################################################################
TH_KNU3_B_ss = StandardScaler()
TH_KNU3_B_ss.fit(TH_KNU3_B)
##############################################################
############################################################################
TH_KNU2_A_ss = StandardScaler()
TH_KNU2_A_ss.fit(TH_KNU2_A)
##############################################################
############################################################################
TH_KNU2_B_ss = StandardScaler()
TH_KNU2_B_ss.fit(TH_KNU2_B)
##############################################################
############################################################################
TH_KNU1_A_ss = StandardScaler()
TH_KNU1_A_ss.fit(TH_KNU1_A)
##############################################################
############################################################################
TH_KNU1_B_ss = StandardScaler()
TH_KNU1_B_ss.fit(TH_KNU1_B)
##############################################################
############################################################################
PALM_1_ss = StandardScaler()
PALM_1_ss.fit(PALM_1)
##############################################################
############################################################################
PALM_2_ss = StandardScaler()
PALM_2_ss.fit(PALM_2)
##############################################################
############################################################################
PALM_3_ss = StandardScaler()
PALM_3_ss.fit(PALM_3)
##############################################################
############################################################################
PALM_4_ss = StandardScaler()
PALM_4_ss.fit(PALM_4)
##############################################################
############################################################################
PALM_5_ss = StandardScaler()
PALM_5_ss.fit(PALM_5)
##############################################################
PALM_6_ss = StandardScaler()
PALM_6_ss.fit(PALM_6)
##############################################################

transformation = [F1_KNU3_A_ss, 
                  F1_KNU3_B_ss,
                  F1_KNU2_A_ss,
                  F1_KNU2_B_ss,
                  F1_KNU1_A_ss,
                  F1_KNU1_B_ss,
                  F2_KNU3_A_ss, 
                  F2_KNU3_B_ss,
                  F2_KNU2_A_ss,
                  F2_KNU2_B_ss,
                  F2_KNU1_A_ss,
                  F2_KNU1_B_ss,
                  F3_KNU3_A_ss,
                  F3_KNU3_B_ss,
                  F3_KNU2_A_ss,
                  F3_KNU2_B_ss,
                  F3_KNU1_A_ss,
                  F3_KNU1_B_ss,
                  F4_KNU3_A_ss,
                  F4_KNU3_B_ss,
                  F4_KNU2_A_ss,
                  F4_KNU2_B_ss,
                  F4_KNU1_A_ss,
                  F4_KNU1_B_ss,
                  TH_KNU3_A_ss,
                  TH_KNU3_B_ss,
                  TH_KNU2_A_ss,
                  TH_KNU2_B_ss,
                  TH_KNU1_A_ss,
                  TH_KNU1_B_ss,
                  PALM_1_ss,    
                  PALM_2_ss,    
                  PALM_3_ss,    
                  PALM_4_ss,
                  PALM_5_ss,
                  PALM_6_ss ]








# StandardScaler().inverse_transform(self, X, copy=None)
#

# %%
from sklearn.decomposition import PCA
#pca = PCA(n_components=1)
#pca.fit(X)



F1_KNU3_A_PCA= PCA(n_components=1)
F1_KNU3_A_PCA.fit(F1_KNU3_A)
F1_KNU3_B_PCA= PCA(n_components=1)
F1_KNU3_B_PCA.fit(F1_KNU3_B)
F1_KNU2_A_PCA= PCA(n_components=1)
F1_KNU2_A_PCA.fit(F1_KNU2_A)
F1_KNU2_B_PCA= PCA(n_components=1)
F1_KNU2_B_PCA.fit(F1_KNU2_B)
F1_KNU1_A_PCA= PCA(n_components=1)
F1_KNU1_A_PCA.fit(F1_KNU1_A)
F1_KNU1_B_PCA= PCA(n_components=1)
F1_KNU1_B_PCA.fit(F1_KNU1_B)
F2_KNU3_A_PCA= PCA(n_components=1)
F2_KNU3_A_PCA.fit(F2_KNU3_A)
F2_KNU3_B_PCA= PCA(n_components=1)
F2_KNU3_B_PCA.fit(F2_KNU3_B)
F2_KNU2_A_PCA= PCA(n_components=1)
F2_KNU2_A_PCA.fit(F2_KNU2_A)
F2_KNU2_B_PCA= PCA(n_components=1)
F2_KNU2_B_PCA.fit(F2_KNU2_B)
F2_KNU1_A_PCA= PCA(n_components=1)
F2_KNU1_A_PCA.fit(F2_KNU1_A)
F2_KNU1_B_PCA= PCA(n_components=1)
F2_KNU1_B_PCA.fit(F2_KNU1_B)
F3_KNU3_A_PCA= PCA(n_components=1)
F3_KNU3_A_PCA.fit(F3_KNU3_A)
F3_KNU3_B_PCA= PCA(n_components=1)
F3_KNU3_B_PCA.fit(F3_KNU3_B)
F3_KNU2_A_PCA= PCA(n_components=1)
F3_KNU2_A_PCA.fit(F3_KNU2_A)
F3_KNU2_B_PCA= PCA(n_components=1)
F3_KNU2_B_PCA.fit(F3_KNU2_B)
F3_KNU1_A_PCA= PCA(n_components=1)
F3_KNU1_A_PCA.fit(F3_KNU1_A)
F3_KNU1_B_PCA= PCA(n_components=1)
F3_KNU1_B_PCA.fit(F3_KNU1_B)
F4_KNU3_A_PCA= PCA(n_components=1)
F4_KNU3_A_PCA.fit(F4_KNU3_A)
F4_KNU3_B_PCA= PCA(n_components=1)
F4_KNU3_B_PCA.fit(F4_KNU3_B)
F4_KNU2_A_PCA= PCA(n_components=1)
F4_KNU2_A_PCA.fit(F4_KNU2_A)
F4_KNU2_B_PCA= PCA(n_components=1)
F4_KNU2_B_PCA.fit(F4_KNU2_B)
F4_KNU1_A_PCA= PCA(n_components=1)
F4_KNU1_A_PCA.fit(F4_KNU1_A)
F4_KNU1_B_PCA= PCA(n_components=1)
F4_KNU1_B_PCA.fit(F4_KNU1_B)
TH_KNU3_A_PCA= PCA(n_components=1)
TH_KNU3_A_PCA.fit(TH_KNU3_A)
TH_KNU3_B_PCA= PCA(n_components=1)
TH_KNU3_B_PCA.fit(TH_KNU3_B)
TH_KNU2_A_PCA= PCA(n_components=1)
TH_KNU2_A_PCA.fit(TH_KNU2_A)
TH_KNU2_B_PCA= PCA(n_components=1)
TH_KNU2_B_PCA.fit(TH_KNU2_B)
TH_KNU1_A_PCA= PCA(n_components=1)
TH_KNU1_A_PCA.fit(TH_KNU1_A)
TH_KNU1_B_PCA= PCA(n_components=1)
TH_KNU1_B_PCA.fit(TH_KNU1_B)
PALM_1_PCA    = PCA(n_components=1)
PALM_1_PCA.fit(PALM_1)
PALM_2_PCA    = PCA(n_components=1)
PALM_2_PCA.fit(PALM_2)
PALM_3_PCA    = PCA(n_components=1)
PALM_3_PCA.fit(PALM_3)
PALM_4_PCA    = PCA(n_components=1)
PALM_4_PCA.fit(PALM_4)
PALM_5_PCA    = PCA(n_components=1)
PALM_5_PCA.fit(PALM_5)
PALM_6_PCA    = PCA(n_components=1)
PALM_6_PCA.fit(PALM_6)
                 
                 




transformation_PCA =[F1_KNU3_A_PCA, 
                  F1_KNU3_B_PCA,
                  F1_KNU2_A_PCA,
                  F1_KNU2_B_PCA,
                  F1_KNU1_A_PCA,
                  F1_KNU1_B_PCA,
                  F2_KNU3_A_PCA, 
                  F2_KNU3_B_PCA,
                  F2_KNU2_A_PCA,
                  F2_KNU2_B_PCA,
                  F2_KNU1_A_PCA,
                  F2_KNU1_B_PCA,
                  F3_KNU3_A_PCA,
                  F3_KNU3_B_PCA,
                  F3_KNU2_A_PCA,
                  F3_KNU2_B_PCA,
                  F3_KNU1_A_PCA,
                  F3_KNU1_B_PCA,
                  F4_KNU3_A_PCA,
                  F4_KNU3_B_PCA,
                  F4_KNU2_A_PCA,
                  F4_KNU2_B_PCA,
                  F4_KNU1_A_PCA,
                  F4_KNU1_B_PCA,
                  TH_KNU3_A_PCA,
                  TH_KNU3_B_PCA,
                  TH_KNU2_A_PCA,
                  TH_KNU2_B_PCA,
                  TH_KNU1_A_PCA,
                  TH_KNU1_B_PCA,
                  PALM_1_PCA,    
                  PALM_2_PCA,    
                  PALM_3_PCA,    
                  PALM_4_PCA,
                  PALM_5_PCA,
                  PALM_6_PCA ]









#print(pca.components_)
#print(pca.mean_)
#print(pca.explained_variance_)

#X_pca = pca.transform(X)

#X_new = pca.inverse_transform(X_pca)

# %%
F1_KNU3_A = transformation[0].transform(F1_KNU3_A)
F1_KNU3_A = transformation_PCA[0].transform(F1_KNU3_A)

F1_KNU3_B = transformation[1].transform(F1_KNU3_B)
F1_KNU3_B = transformation_PCA[1].transform(F1_KNU3_B)

F1_KNU2_A = transformation[2].transform(F1_KNU2_A)
F1_KNU2_A = transformation_PCA[2].transform(F1_KNU2_A)

F1_KNU2_B = transformation[3].transform(F1_KNU2_B)
F1_KNU2_B = transformation_PCA[3].transform(F1_KNU2_B)

F1_KNU1_A = transformation[4].transform(F1_KNU1_A)
F1_KNU1_A = transformation_PCA[4].transform(F1_KNU1_A)

F1_KNU1_B = transformation[5].transform(F1_KNU1_B)
F1_KNU1_B = transformation_PCA[5].transform(F1_KNU1_B)

F2_KNU3_A = transformation[6].transform(F2_KNU3_A)
F2_KNU3_A = transformation_PCA[6].transform(F2_KNU3_A)

F2_KNU3_B = transformation[7].transform(F2_KNU3_B)
F2_KNU3_B = transformation_PCA[7].transform(F2_KNU3_B)

F2_KNU2_A = transformation[8].transform(F2_KNU2_A)
F2_KNU2_A = transformation_PCA[8].transform(F2_KNU2_A)

F2_KNU2_B = transformation[9].transform(F2_KNU2_B)
F2_KNU2_B = transformation_PCA[9].transform(F2_KNU2_B)

F2_KNU1_A = transformation[10].transform(F2_KNU1_A)
F2_KNU1_A = transformation_PCA[10].transform(F2_KNU1_A)

F2_KNU1_B = transformation[11].transform(F2_KNU1_B)
F2_KNU1_B = transformation_PCA[11].transform(F2_KNU1_B)

F3_KNU3_A = transformation[12].transform(F3_KNU3_A)
F3_KNU3_A = transformation_PCA[12].transform(F3_KNU3_A)

F3_KNU3_B = transformation[13].transform(F3_KNU3_B)
F3_KNU3_B = transformation_PCA[13].transform(F3_KNU3_B)

F3_KNU2_A = transformation[14].transform(F3_KNU2_A)
F3_KNU2_A = transformation_PCA[14].transform(F3_KNU2_A)

F3_KNU2_B = transformation[15].transform(F3_KNU2_B)
F3_KNU2_B = transformation_PCA[15].transform(F3_KNU2_B)

F3_KNU1_A = transformation[16].transform(F3_KNU1_A)
F3_KNU1_A = transformation_PCA[16].transform(F3_KNU1_A)

F3_KNU1_B = transformation[17].transform(F3_KNU1_B)
F3_KNU1_B = transformation_PCA[17].transform(F3_KNU1_B)

F4_KNU3_A = transformation[18].transform(F4_KNU3_A)
F4_KNU3_A = transformation_PCA[18].transform(F4_KNU3_A)

F4_KNU3_B = transformation[19].transform(F4_KNU3_B)
F4_KNU3_B = transformation_PCA[19].transform(F4_KNU3_B)

F4_KNU2_A = transformation[20].transform(F4_KNU2_A)
F4_KNU2_A = transformation_PCA[20].transform(F4_KNU2_A)

F4_KNU2_B = transformation[21].transform(F4_KNU2_B)
F4_KNU2_B = transformation_PCA[21].transform(F4_KNU2_B)

F4_KNU1_A = transformation[22].transform(F4_KNU1_A)
F4_KNU1_A = transformation_PCA[22].transform(F4_KNU1_A)

F4_KNU1_B = transformation[23].transform(F4_KNU1_B)
F4_KNU1_B = transformation_PCA[23].transform(F4_KNU1_B)

TH_KNU3_A = transformation[24].transform(TH_KNU3_A)
TH_KNU3_A = transformation_PCA[24].transform(TH_KNU3_A)

TH_KNU3_B = transformation[25].transform(TH_KNU3_B)
TH_KNU3_B = transformation_PCA[25].transform(TH_KNU3_B)

TH_KNU2_A = transformation[26].transform(TH_KNU2_A)
TH_KNU2_A = transformation_PCA[26].transform(TH_KNU2_A)

TH_KNU2_B = transformation[27].transform(TH_KNU2_B)
TH_KNU2_B = transformation_PCA[27].transform(TH_KNU2_B)

TH_KNU1_A = transformation[28].transform(TH_KNU1_A)
TH_KNU1_A = transformation_PCA[28].transform(TH_KNU1_A)

TH_KNU1_B = transformation[29].transform(TH_KNU1_B)
TH_KNU1_B = transformation_PCA[29].transform(TH_KNU1_B)

PALM_1    = transformation[30].transform(PALM_1 )
PALM_1    = transformation_PCA[30].transform(PALM_1 )

PALM_2    = transformation[31].transform(PALM_2)
PALM_2    = transformation_PCA[31].transform(PALM_2)

PALM_3    = transformation[32].transform(PALM_3 )
PALM_3    = transformation_PCA[32].transform(PALM_3 )

PALM_4    = transformation[33].transform(PALM_4)
PALM_4    = transformation_PCA[33].transform(PALM_4)

PALM_5    = transformation[34].transform(PALM_5)
PALM_5    = transformation_PCA[34].transform(PALM_5)

PALM_6    = transformation[35].transform(PALM_6)
PALM_6    = transformation_PCA[35].transform(PALM_6)

# %%
F1_KNU3_A_Df = pd.DataFrame(data = F1_KNU3_A, columns = ['F1_KNU3_A'])


F1_KNU3_B_Df = pd.DataFrame(data = F1_KNU3_B, columns = ['F1_KNU3_B'])


F1_KNU2_A_Df  = pd.DataFrame(data = F1_KNU2_A, columns = ['F1_KNU2_A'])


F1_KNU2_B_Df = pd.DataFrame(data = F1_KNU2_B, columns = ['F1_KNU2_B']) 


F1_KNU1_A_Df = pd.DataFrame(data = F1_KNU1_A, columns = ['F1_KNU1_A']) 


F1_KNU1_B_Df = pd.DataFrame(data = F1_KNU1_B, columns = ['F1_KNU1_B'])  


F2_KNU3_A_Df = pd.DataFrame(data = F2_KNU3_A, columns = ['F2_KNU3_A'])  


F2_KNU3_B_Df  = pd.DataFrame(data = F2_KNU3_B, columns = ['F2_KNU3_B'])


F2_KNU2_A_Df  = pd.DataFrame(data = F2_KNU2_A, columns = ['F2_KNU2_A'])


F2_KNU2_B_Df  = pd.DataFrame(data = F2_KNU2_B, columns = ['F2_KNU2_B'])


F2_KNU1_A_Df  = pd.DataFrame(data = F2_KNU1_A, columns = ['F2_KNU1_A'])


F2_KNU1_B_Df  = pd.DataFrame(data = F2_KNU1_B, columns = ['F2_KNU1_B'])


F3_KNU3_A_Df  = pd.DataFrame(data = F3_KNU3_A, columns = ['F3_KNU3_A'])


F3_KNU3_B_Df  = pd.DataFrame(data = F3_KNU3_B, columns = ['F3_KNU3_B'])


F3_KNU2_A_Df  = pd.DataFrame(data = F3_KNU2_A, columns = ['F3_KNU2_A'])


F3_KNU2_B_Df  = pd.DataFrame(data = F3_KNU2_B, columns = ['F3_KNU2_B'])


F3_KNU1_A_Df = pd.DataFrame(data = F3_KNU1_A, columns = ['F3_KNU1_A'])


F3_KNU1_B_Df  = pd.DataFrame(data = F3_KNU1_B, columns = ['F3_KNU1_B'])


F4_KNU3_A_Df  = pd.DataFrame(data = F4_KNU3_A, columns = ['F4_KNU3_A'])


F4_KNU3_B_Df  = pd.DataFrame(data = F4_KNU3_B, columns = ['F4_KNU3_B'])


F4_KNU2_A_Df  = pd.DataFrame(data = F4_KNU2_A, columns = ['F4_KNU2_A'])


F4_KNU2_B_Df  = pd.DataFrame(data = F4_KNU2_B, columns = ['F4_KNU2_B'])


F4_KNU1_A_Df = pd.DataFrame(data = F4_KNU1_A, columns = ['F4_KNU1_A'])


F4_KNU1_B_Df  = pd.DataFrame(data = F4_KNU1_B, columns = ['F4_KNU1_B'])


TH_KNU3_A_Df  = pd.DataFrame(data = TH_KNU3_A, columns = ['TH_KNU3_A'])


TH_KNU3_B_Df  = pd.DataFrame(data =TH_KNU3_B, columns = ['TH_KNU3_B'])


TH_KNU2_A_Df  = pd.DataFrame(data = TH_KNU2_A, columns = ['TH_KNU2_A'])


TH_KNU2_B_Df  = pd.DataFrame(data = TH_KNU2_B, columns = ['TH_KNU2_B'])


TH_KNU1_A_Df = pd.DataFrame(data = TH_KNU1_A, columns = ['TH_KNU1_A'])


TH_KNU1_B_Df  = pd.DataFrame(data = TH_KNU1_B, columns = ['TH_KNU1_B'])


PALM_1_Df     = pd.DataFrame(data = PALM_1, columns = ['PALM_1'])
  

PALM_2_Df     = pd.DataFrame(data = PALM_2, columns = ['PALM_2'])
 

PALM_3_Df     = pd.DataFrame(data = PALM_3, columns = ['PALM_3'])


PALM_4_Df     = pd.DataFrame(data = PALM_4, columns = ['PALM_4'])
  

PALM_5_Df    = pd.DataFrame(data = PALM_5, columns = ['PALM_5'])


PALM_6_Df    = pd.DataFrame(data = PALM_6, columns = ['PALM_6'])
 

output_final_file = pd.concat([ F1_KNU3_A_Df, 

                                F1_KNU3_B_Df ,

                                F1_KNU2_A_Df  ,

                                F1_KNU2_B_Df ,

                                F1_KNU1_A_Df ,

                                F1_KNU1_B_Df ,

                                F2_KNU3_A_Df,

                                F2_KNU3_B_Df , 

                                F2_KNU2_A_Df ,

                                F2_KNU2_B_Df  ,

                                F2_KNU1_A_Df ,

                                F2_KNU1_B_Df  ,

                                F3_KNU3_A_Df  ,

                                F3_KNU3_B_Df  ,

                                F3_KNU2_A_Df ,

                                F3_KNU2_B_Df  ,

                                F3_KNU1_A_Df ,

                                F3_KNU1_B_Df  ,

                                F4_KNU3_A_Df  ,

                                F4_KNU3_B_Df  ,

                                F4_KNU2_A_Df  ,

                                F4_KNU2_B_Df  ,

                                F4_KNU1_A_Df ,

                                F4_KNU1_B_Df  ,

                                TH_KNU3_A_Df  ,

                                TH_KNU3_B_Df  ,

                                TH_KNU2_A_Df  ,

                                TH_KNU2_B_Df ,

                                TH_KNU1_A_Df ,

                                TH_KNU1_B_Df  ,

                                PALM_1_Df    ,

                                PALM_2_Df     ,

                                PALM_3_Df     ,

                                PALM_4_Df     ,

                                PALM_5_Df    ,

                                PALM_6_Df    ] , axis=1, join='inner')

# %%
# code to save new pca file from 3d to 1d
output_final_file.to_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\pca_file.csv', index=False)

# %%
# testing code
test_X = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\test\\joint_x.csv',index_col=None)
test_Y = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\test\\joint_y.csv',index_col=None)
test_Z = pd.read_csv('C:\\Users\\aliar\\OneDrive\\Desktop\\developing pca\\test\\joint_z.csv',index_col=None) 


F1_KNU3_A_x_test = test_X[['F1_KNU3_A']]
F1_KNU3_A_y_test = test_Y[['F1_KNU3_A']]
F1_KNU3_A_z_test = test_Z[['F1_KNU3_A']]


F1_KNU3_A_test = pd.concat([F1_KNU3_A_x_test, F1_KNU3_A_y_test,F1_KNU3_A_z_test], axis=1, join='inner')

F1_KNU3_A_test = transformation[0].transform(F1_KNU3_A_test)
F1_KNU3_A_test = transformation_PCA[0].transform(F1_KNU3_A_test)

F1_KNU3_A_test = transformation_PCA[0].inverse_transform(F1_KNU3_A_test)
F1_KNU3_A_test = transformation[0].inverse_transform(F1_KNU3_A_test)

print(F1_KNU3_A_test)
# Out:
# [[0.11398853 0.94706597 0.15570117]
#  [0.11426431 0.94675416 0.15572776]
#  [0.11415721 0.94687525 0.15571744]
#  ...
#  [0.81797716 0.1510862  0.22357786]
#  [0.81767952 0.15142273 0.22354916]
#  [0.81770835 0.15139014 0.22355194]]
