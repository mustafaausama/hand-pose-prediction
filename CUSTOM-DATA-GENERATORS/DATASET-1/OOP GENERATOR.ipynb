# %%
class Generator():
    def __init__(self):
      #  pass
        import numpy as np
        import pandas as pd
        import h5py
        self.B1COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B1Counting_SK.csv')
        self.B2COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B2Counting_SK.csv')
        self.B3COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B3Counting_SK.csv')
        self.B4COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B4Counting_SK.csv')
        self.B5COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B5Counting_SK.csv')
        self.B6COUNT = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B6Counting_SK.csv')
        self.B1RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B1Random_SK.csv')
        self.B2RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B2Random_SK.csv')
        self.B3RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B3Random_SK.csv')
        self.B4RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B4Random_SK.csv')
        self.B5RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B5Random_SK.csv')
        self.B6RAND = pd.read_csv('C:/Users/aliar/OneDrive/Desktop/FINAL_CSV/B6Random_SK.csv')
        
    def get_data(self,file_no,random_or_counting,dataset_no):
        import h5py
        import numpy as np
        if random_or_counting==0:
               self.x = 'Counting'
        if random_or_counting==1:        
               self.x = 'Random'
        if (random_or_counting!=1 & random_or_counting!=0):
               print("random_counting value to be 1 or 2 ! raise error")
                        
        self.x = str('B')+str(dataset_no)+self.x
        print(self.x)
        # x == full dataset name i-e b5counting/b1 random or any other possible combination
        filename = 'E:/FYP/'+str(self.x)+'/'+str(file_no)+'.h5'
        print(filename)
           # getting 3d input from h5 files
        h5 = h5py.File(filename,'r')
        input = np.array(h5['TSDF'])
        input = np.reshape(input,(32,32,32,1))
                # VSTOXX futures data
        h5.close()           
         
        if random_or_counting == 0:
                        if dataset_no == 1 :
                            output = self.B1COUNT.iloc[file_no].values
                        if dataset_no == 2 :
                            output = self.B2COUNT.iloc[file_no].values
                        if dataset_no == 3 :
                            output = self.B3COUNT.iloc[file_no].values
                        if dataset_no == 4 :
                            output = self.B4COUNT.iloc[file_no].values
                        if dataset_no == 5 :
                            output = self.B5COUNT.iloc[file_no].values
                        if dataset_no == 6 :        
                            output = self.B6COUNT.iloc[file_no].values
        if random_or_counting == 1:
                        
                        if dataset_no == 1 :
                            output = self.B1RAND.iloc[file_no].values
                        if dataset_no == 2 :
                            output = self.B2RAND.iloc[file_no].values
                        if dataset_no == 3 :
                            output = self.B3RAND.iloc[file_no].values
                        if dataset_no == 4 :
                            output = self.B4RAND.iloc[file_no].values
                        if dataset_no == 5 :
                            output = self.B5RAND.iloc[file_no].values
                        if dataset_no == 6 :        
                            output = self.B6RAND.iloc[file_no].values           
            
            
        return input,output
